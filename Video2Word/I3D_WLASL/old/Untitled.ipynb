# %%
from load_dataset import _label
from os import listdir

# %%
nameset = set()
for filename in listdir('train_processed'):
    nameset.add(_label(filename))
unique_labels = sorted(nameset)
with open('labels.txt', mode='wt', encoding='utf-8') as myfile:
    myfile.write('\n'.join(unique_labels))

# %%
len(listdir('train_processed'))
# Out:
# 8250

# %%
len(unique_labels)

# %%
! pip install "dm-sonnet<2"
# Out:
# Collecting dm-sonnet<2
#   Downloading dm_sonnet-1.36-py3-none-any.whl (665 kB)
#      |████████████████████████████████| 665 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.7/site-packages (from dm-sonnet<2) (1.12.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from dm-sonnet<2) (0.9.0)
# Collecting tensorflow-probability<0.9.0,>=0.8.0
#   Downloading tensorflow_probability-0.8.0-py2.py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 49.9 MB/s eta 0:00:01
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from dm-sonnet<2) (1.14.0)
# Collecting semantic-version
#   Downloading semantic_version-2.8.4-py2.py3-none-any.whl (15 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from tensorflow-probability<0.9.0,>=0.8.0->dm-sonnet<2) (1.18.1)
# Collecting cloudpickle==1.1.1
#   Downloading cloudpickle-1.1.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: gast<0.3,>=0.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow-probability<0.9.0,>=0.8.0->dm-sonnet<2) (0.2.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from tensorflow-probability<0.9.0,>=0.8.0->dm-sonnet<2) (4.4.1)
# ERROR: gym 0.16.0 has requirement cloudpickle~=1.2.0, but you'll have cloudpickle 1.1.1 which is incompatible.
# Installing collected packages: cloudpickle, tensorflow-probability, semantic-version, contextlib2, dm-sonnet
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.2.2
#     Uninstalling cloudpickle-1.2.2:
#       Successfully uninstalled cloudpickle-1.2.2
# Successfully installed cloudpickle-1.1.1 contextlib2-0.6.0.post1 dm-sonnet-1.36 semantic-version-2.8.4 tensorflow-probability-0.8.0

# %%
from train_model import train

# %%
train(num_epochs=25, beta=0.25, lr=5e-3, evaluate_test_dset=False)
# Out:
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:39: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:39: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:40: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:69: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/sonnet/python/modules/conv.py:325: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:37: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:41: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/sonnet/python/modules/conv.py:330: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:17: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:23: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:86: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:86: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:92: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/jovyan/work/build_graph.py:108: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
#
# train_dset len=5280; val_dset len=1320; test_dset len=1650
#
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:66: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Statistics restored
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:100: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:101: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/jovyan/work/train_model.py:102: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# INFO:tensorflow:Restoring parameters from data/checkpointz/rgb_imagenet/model.ckpt
# INFO:tensorflow:RGB checkpoint restored
# INFO:tensorflow:Restoring parameters from data/checkpointz/training/model.ckpt
# INFO:tensorflow:Training checkpoint restored
# Starting epoch 0
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 0, loss = 7.0346
# Iteration 1, loss = 7.4115
# Iteration 2, loss = 5.8648
# Iteration 3, loss = 8.4007
# Iteration 4, loss = 6.0099
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 5, loss = 9.0972
# Iteration 6, loss = 8.0937
# Iteration 7, loss = 6.0782
# Iteration 8, loss = 7.2458
# Iteration 9, loss = 6.1079
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 10, loss = 5.9223
# Iteration 11, loss = 7.6133
# Iteration 12, loss = 5.5704
# Iteration 13, loss = 9.1637
# Iteration 14, loss = 6.3049
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 15, loss = 6.6499
# Iteration 16, loss = 7.3902
# Iteration 17, loss = 6.2165
# Iteration 18, loss = 6.8895
# Iteration 19, loss = 5.6739
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 20, loss = 9.1326
# Iteration 21, loss = 8.2045
# Iteration 22, loss = 6.8213
# Iteration 23, loss = 7.4198
# Iteration 24, loss = 9.1146
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 25, loss = 9.1120
# Iteration 26, loss = 8.3393
# Iteration 27, loss = 9.1015
# Iteration 28, loss = 9.1052
# Iteration 29, loss = 6.0663
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 2 / 100 correct (2.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 30, loss = 6.1144
# Iteration 31, loss = 7.3142
# Iteration 32, loss = 8.4217
# Iteration 33, loss = 5.5646
# Iteration 34, loss = 7.7235
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 35, loss = 7.4685
# Iteration 36, loss = 5.7835
# Iteration 37, loss = 7.5536
# Iteration 38, loss = 8.7773
# Iteration 39, loss = 6.4159
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 40, loss = 6.9863
# Iteration 41, loss = 6.5806
# Iteration 42, loss = 6.9198
# Iteration 43, loss = 9.0829
# Iteration 44, loss = 7.4946
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 45, loss = 6.9267
# Iteration 46, loss = 5.8984
# Iteration 47, loss = 7.5632
# Iteration 48, loss = 5.8143
# Iteration 49, loss = 6.2631
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 50, loss = 7.5605
# Iteration 51, loss = 5.4248
# Iteration 52, loss = 5.5409
# Iteration 53, loss = 6.7872
# Iteration 54, loss = 8.1754
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 55, loss = 5.4177
# Iteration 56, loss = 7.5526
# Iteration 57, loss = 5.5273
# Iteration 58, loss = 5.9620
# Iteration 59, loss = 5.8027
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 60, loss = 6.9144
# Iteration 61, loss = 6.5472
# Iteration 62, loss = 6.5389
# Iteration 63, loss = 5.8527
# Iteration 64, loss = 5.8984
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 65, loss = 7.5694
# Iteration 66, loss = 6.5744
# Iteration 67, loss = 9.0895
# Iteration 68, loss = 5.8082
# Iteration 69, loss = 7.6498
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 70, loss = 6.0904
# Iteration 71, loss = 5.6035
# Iteration 72, loss = 6.8095
# Iteration 73, loss = 9.0942
# Iteration 74, loss = 7.5054
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 75, loss = 9.0312
# Iteration 76, loss = 9.0955
# Iteration 77, loss = 6.4031
# Iteration 78, loss = 7.3382
# Iteration 79, loss = 8.3666
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 80, loss = 6.4832
# Iteration 81, loss = 7.3475
# Iteration 82, loss = 5.6245
# Iteration 83, loss = 5.5723
# Iteration 84, loss = 7.0517
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 85, loss = 9.1008
# Iteration 86, loss = 7.9009
# Iteration 87, loss = 9.0996
# Iteration 88, loss = 5.5608
# Iteration 89, loss = 9.1027
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 90, loss = 8.9861
# Iteration 91, loss = 8.3425
# Iteration 92, loss = 9.1057
# Iteration 93, loss = 6.5935
# Iteration 94, loss = 6.4753
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 2 / 100 correct (2.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 95, loss = 5.2533
# Iteration 96, loss = 6.4848
# Iteration 97, loss = 6.1159
# Iteration 98, loss = 6.4950
# Iteration 99, loss = 5.5644
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 100, loss = 7.9033
# Iteration 101, loss = 9.1140
# Iteration 102, loss = 5.7858
# Iteration 103, loss = 8.9959
# Iteration 104, loss = 6.6762
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 105, loss = 8.4321
# Iteration 106, loss = 7.9329
# Iteration 107, loss = 9.1197
# Iteration 108, loss = 9.1204
# Iteration 109, loss = 5.9329
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 110, loss = 6.2833
# Iteration 111, loss = 9.1206
# Iteration 112, loss = 8.2489
# Iteration 113, loss = 9.1232
# Iteration 114, loss = 7.4855
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 115, loss = 6.2200
# Iteration 116, loss = 6.9982
# Iteration 117, loss = 9.1293
# Iteration 118, loss = 7.3162
# Iteration 119, loss = 9.1282
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 120, loss = 9.1300
# Iteration 121, loss = 6.0078
# Iteration 122, loss = 6.3799
# Iteration 123, loss = 7.7200
# Iteration 124, loss = 7.0451
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 2 / 100 correct (2.00%)
# Iteration 125, loss = 7.6591
# Iteration 126, loss = 5.7439
# Iteration 127, loss = 6.4432
# Iteration 128, loss = 7.1975
# Iteration 129, loss = 6.5601
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 2 / 100 correct (2.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 130, loss = 6.7582
# Iteration 131, loss = 5.9313
# Iteration 132, loss = 6.3101
# Iteration 133, loss = 6.0199
# Iteration 134, loss = 8.5558
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 135, loss = 5.8748
# Iteration 136, loss = 6.3900
# Iteration 137, loss = 7.3502
# Iteration 138, loss = 7.4648
# Iteration 139, loss = 5.3253
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 140, loss = 5.9174
# Iteration 141, loss = 9.1544
# Iteration 142, loss = 6.7167
# Iteration 143, loss = 7.7598
# Iteration 144, loss = 9.1583
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 145, loss = 5.7581
# Iteration 146, loss = 9.1590
# Iteration 147, loss = 9.1612
# Iteration 148, loss = 7.0319
# Iteration 149, loss = 7.1669
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 1 / 100 correct (1.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 150, loss = 5.9900
# Iteration 151, loss = 7.5907
# Iteration 152, loss = 9.1676
# Iteration 153, loss = 7.7479
# Iteration 154, loss = 7.3903
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 0 / 100 correct (0.00%)
# Iteration 155, loss = 5.6564
# Iteration 156, loss = 5.8803
# Iteration 157, loss = 9.1748
# Iteration 158, loss = 6.4895
# Iteration 159, loss = 4.9953
#
# Training model saved in path: data/checkpointz/training/model.ckpt
#
# RGB model saved in path: data/checkpointz/rgb_imagenet/model.ckpt
# Train: 0 / 100 correct (0.00%)
# Val: 1 / 100 correct (1.00%)
# Iteration 160, loss = 5.9181
# Iteration 161, loss = 9.1788
# Iteration 162, loss = 8.4640
# Iteration 163, loss = 8.5593
